# %% [markdown]
# # **LetsGrowMore - Data Science Internship**
#
# # **TASK 2 -  Exploratory Data Analysis on Dataset - Terrorism**

# %% [markdown]
# ### Author : TANAY CHOUBEY
# [![alt text](https://logoeps.com/wp-content/uploads/2014/02/25231-github-cat-in-a-circle-icon-vector-icon-vector-eps.png "Git Hub Link")](https://github.com/Tanay-Choubey)

# %% [markdown]
# ### Problem Statement: As a security/defense analyst, try to find out the hot zone of terrorism. You can choose any of the tools of your choice  (Python/R/Tableau/PowerBI/Excel/SAP/SAS)
#
# ### Dataset link: https://bit.ly/2TK5Xn5

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading & Understanding the dataset

# %%
data = pd.read_csv('globalterrorismdb_0718dist.csv', encoding = 'latin1')
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %% [markdown]
# ### Arranging & Renaming the dataset

# %%
data=data[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]

# %%
data.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack_Type","targtype1_txt":"Target_Type",
                   "gname":"Group","motive":"Motive","weaptype1_txt":"Weapon_Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add_Notes"}, inplace=True)

# %%
data.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack_Type                  Target_Type  \
# ...

# %% [markdown]
# ### Checking & Removing null values

# %%
data.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack_Type            0
# Target_Type            0
# Group                  0
# Motive            131130
# Weapon_Type            0
# Killed             10313
# Wounded            16311
# Add_Notes         153402
# dtype: int64

# %%
data.shape
# Out:
# (181691, 19)

# %%
data_new = data.dropna(axis=0)

# %%
data_new.head()
# Out:
#     Year  Month  Day        Country         Region Province/State  \
# 14  1970      1    9  United States  North America    Puerto Rico
# 17  1970      1   12  United States  North America       New York
# 22  1970      1   19  United States  North America     Washington
# 24  1970      1   19  United States  North America     New Jersey
# 30  1970      1   25  United States  North America       New York
#
#              City   Latitude   Longitude                 Location  \
# 14    Rio Piedras  18.386932  -66.061127  Caparra Shopping Center
# 17  New York City  40.697132  -73.931351                 Brooklyn
# 22        Seattle  47.610786 -122.331306       Seattle University
# 24    Jersey City  40.717892  -74.067467        Front of building
# 30  New York City  40.697132  -73.931351                Manhattan
#
#                                               Summary  \
# 14  1/9/1970:  The Armed Commandos of Liberation c...
# 17  1/12/1970: Unknown perpetrators threw a pipe b...
# ...

# %%
data_new.shape
# Out:
# (6765, 19)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6765 entries, 14 to 181672
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            6765 non-null   int64
#  1   Month           6765 non-null   int64
#  2   Day             6765 non-null   int64
#  3   Country         6765 non-null   object
#  4   Region          6765 non-null   object
#  5   Province/State  6765 non-null   object
#  6   City            6765 non-null   object
#  7   Latitude        6765 non-null   float64
#  8   Longitude       6765 non-null   float64
#  9   Location        6765 non-null   object
#  10  Summary         6765 non-null   object
#  11  Attack_Type     6765 non-null   object
#  12  Target_Type     6765 non-null   object
#  13  Group           6765 non-null   object
#  14  Motive          6765 non-null   object
#  15  Weapon_Type     6765 non-null   object
#  16  Killed          6765 non-null   float64
# ...

# %% [markdown]
# ### Number of Terrorist Activities each Year

# %%
year = data_new['Year'].unique()
years_count = data_new['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (15,10))
sns.barplot(x = year,
            y = years_count,
            palette = 'muted')
plt.xticks(rotation = 50)
plt.xlabel('Years', fontsize = 20)
plt.ylabel('Number of attacks each year', fontsize = 20)
plt.title('Attacks In Years', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Attacks In Years')

# %% [markdown]
# ### Terrorist Activities by Region in each Year through Area Plot

# %%
pd.crosstab(data_new.Year, data_new.Region).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities by Region in each Year', size = 25)
plt.xlabel('Year' , size = 20)
plt.ylabel('Number of Attacks', size = 20)
plt.show()

# %% [markdown]
# ### Most Affected Cities

# %%
data_new['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10), color='indianred')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize = 20)
plt.ylabel("Number of attack",fontsize = 20)
plt.title("Most Affected Cities",fontsize = 25)
plt.show()

# %% [markdown]
# ### Top Terrorist Groups

# %%
data_new['Group'].value_counts()[:10]
# Out:
# Unknown                                             2274
# Revolutionary Armed Forces of Colombia (FARC)        399
# Communist Party of India - Maoist (CPI-Maoist)       289
# Taliban                                              258
# Algerian Islamic Extremists                          229
# Liberation Tigers of Tamil Eelam (LTTE)              205
# Islamic State of Iraq and the Levant (ISIL)          164
# Tehrik-i-Taliban Pakistan (TTP)                      151
# Al-Qaida in Iraq                                     131
# Salafist Group for Preaching and Fighting (GSPC)     114
# Name: Group, dtype: int64

# %%
data_new[['Group','Killed']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('Killed',ascending=False).head(10).plot(kind='bar', color='indianred',figsize=(20,10))
plt.title("Top Terrorist Groups With Respect To People Killed",fontsize = 25)
plt.xlabel("Group Name",fontsize = 20)
plt.ylabel("Number Of People Killed",fontsize = 20)
plt.show()

# %% [markdown]
# ### Most Affected Countries

# %%
plt.subplots(figsize=(20,10))
plt.bar(data_new['Country'].value_counts()[:10].index,data_new['Country'].value_counts()[:10].values)
plt.title('Top Countries Affected', fontsize = 25)
plt.xlabel('Countries', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ### Country wise Casualities

# %%
lis=[]
total=[]
for i in data_new['Country'].value_counts().index:
    Total = data_new.loc[data_new['Country'] == i, 'Killed'].sum()
    lis.append([i,Total])
lis=sorted(lis,key=lambda x:x[1],reverse=True)
print(*lis[:20])   #country wise casuality over the years from 1970 to 2017
# Out:
# ['Iraq', 6732.0] ['Pakistan', 3628.0] ['Afghanistan', 2043.0] ['India', 1799.0] ['Algeria', 1260.0] ['Sri Lanka', 1127.0] ['Nigeria', 808.0] ['Colombia', 511.0] ['Russia', 355.0] ['Somalia', 307.0] ['Syria', 279.0] ['Turkey', 250.0] ['Philippines', 236.0] ['Democratic Republic of the Congo', 235.0] ['Yemen', 219.0] ['Thailand', 188.0] ['Central African Republic', 178.0] ['Angola', 177.0] ['United States', 175.0] ['Uganda', 173.0]

# %%
country=[]
casuality=[]
for i in lis[:11]:
    country.append(i[0])
    casuality.append(i[1])
    
fig=plt.figure(figsize=(20,10))
plt.title("Country wise Casualities (1970-2017)",fontsize=25)
plt.xlabel("Country",size=25)
plt.ylabel("Casuality",size=25)
sns.barplot(x=country,y=casuality)
plt.show()

# %% [markdown]
# ### Conclusion :

# %%
print("Country with the most attacks:",data_new['Country'].value_counts().idxmax())
print("City with the most attacks:",data_new['City'].value_counts().index[0])
print("Region with the most attacks:",data_new['Region'].value_counts().idxmax())
print("Year with the most attacks:",data_new['Year'].value_counts().idxmax())
print("Month with the most attacks:",data_new['Month'].value_counts().idxmax())
print("Group with the most attacks:",data_new['Group'].value_counts().index[1])
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: South Asia
# Year with the most attacks: 2010
# Month with the most attacks: 6
# Group with the most attacks: Revolutionary Armed Forces of Colombia (FARC)

# %% [markdown]
# # **--------------------------------------------Thank You--------------------------------------------**
